# %%
import pandas as pd
# This link is from my github branch for the project
csv_url = "https://raw.githubusercontent.com/hyunyuk/Project_3/AA_branch/Data/Child_Care_Programs_Cleaned.csv"
data = pd.read_csv(csv_url)
data.head(5)
# Out:
#    Facility ID Program Type Region Code       County Facility Status  \
# 0         6602         GFDC        LIRO       Nassau         License
# 1        27105          FDC         RRO       Monroe    Registration
# 2        39236          DCC         SRO       Broome         License
# 3        40146          DCC         ARO   Rensselaer         License
# 4        40572          DCC         YRO  Westchester         License
#
#                                        Facility Name Street Number  \
# 0                                GLORIA'S CHILD CARE           NaN
# 1                                       Pease, Tammy           NaN
# 2                    Family Enrichment Network, Inc.           287
# 3  Cath. Charities of the Diocese of Alb. @Sunnyside             0
# 4               Saint  Peter's Child Care Center Inc           204
#
#               Street Name        City State  ...  School District Name  \
# 0                     NaN   UNIONDALE    NY  ...             Uniondale
# 1                     NaN   Rochester    NY  ...                Greece
# 2             Prospect St  Binghamton    NY  ...            Binghamton
# 3  9th St. & Ingalls Ave.        Troy    NY  ...                   NaN
# 4           Hawthorne Ave     Yonkers    NY  ...               Yonkers
#
#                                 Capacity Description Infant Capacity  \
# 0  12 children, ages 6 weeks to 12 years AND 4 ad...               0
# 1  6 children, ages 6 weeks to 12 years AND 2 add...               0
# 2                                    36 Preschoolers               0
# 3            8 Infants, 10 Toddlers, 21 Preschoolers               8
# 4                                   157 Preschoolers               0
#
#   Toddler Capacity Preschool Capacity School Age Capacity  Total Capacity  \
# 0                0                  0                   4              16
# 1                0                  0                   2               8
# 2                0                 36                   0              36
# 3               10                 21                   0              39
# 4                0                157                   0             157
#
#                                    Program Profile   Latitude  Longitude
# 0   https://hs.ocfs.ny.gov/dcfs/Profile/Index/6602        NaN        NaN
# 1  https://hs.ocfs.ny.gov/dcfs/Profile/Index/27105        NaN        NaN
# 2  https://hs.ocfs.ny.gov/dcfs/Profile/Index/39236  42.114939 -75.937930
# 3  https://hs.ocfs.ny.gov/dcfs/Profile/Index/40146        NaN        NaN
# 4  https://hs.ocfs.ny.gov/dcfs/Profile/Index/40572  40.925379 -73.902449
#
# [5 rows x 24 columns]

# %%
data.to_json(r"C:\Users\alaa3\Desktop\Project_3\Data\Child_Care.json")
