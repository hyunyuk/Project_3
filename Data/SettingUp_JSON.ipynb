# %%
import pandas as pd
# This link is from my github branch for the project
csv_url = "https://raw.githubusercontent.com/hyunyuk/Project_3/AA_branch/Data/Resources/Child_Care_Regulated_Programs_API.csv"
data = pd.read_csv(csv_url)
data.head(5)
# Out:
#    Facility ID Program Type Region Code       County Facility Status  \
# 0         6602         GFDC        LIRO       Nassau         License
# 1        27105          FDC         RRO       Monroe    Registration
# 2        39236          DCC         SRO       Broome         License
# 3        40146          DCC         ARO   Rensselaer         License
# 4        40572          DCC         YRO  Westchester         License
#
#                                        Facility Name Address Omitted  \
# 0                                GLORIA'S CHILD CARE               Y
# 1                                       Pease, Tammy               Y
# 2                    Family Enrichment Network, Inc.             NaN
# 3  Cath. Charities of the Diocese of Alb. @Sunnyside             NaN
# 4               Saint  Peter's Child Care Center Inc             NaN
#
#   Street Number             Street Name Additional Address  ...  \
# 0           NaN                     NaN                NaN  ...
# ...

# %%
data.to_json(r"C:\Users\alaa3\Desktop\Project_3\Data\Child_Care.json")
